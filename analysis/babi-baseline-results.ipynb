# %%
# %matplotlib inline

# %%
import json
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
from pandas.io.json import json_normalize

# %%
def CustomParser(data):
    return json.loads(data)

# Read csv file
filename = 'result.csv'
df = pd.read_csv(filename, sep=';', converters={'db_parameters':CustomParser, 'model_cfg': CustomParser})
df[sorted(df['db_parameters'][0].keys())] = df['db_parameters'].apply(pd.Series)
df[sorted(df['model_cfg'][0].keys())] = df['model_cfg'].apply(pd.Series)

# %%
import os
FOLDER='../results/'

folders = set(os.listdir(FOLDER))
folders.remove('_sources')

result = {
    'acc':[],
    'f1':[],
    'db':[],
    'task':[],
    'model':[]
}

for root_folder in folders:
    for run_id in os.listdir(FOLDER+root_folder):
        current_folder = FOLDER+root_folder+'/'+run_id

        metrics_file = current_folder+'/metrics-test.csv'
        config_file = current_folder+'/config.json'
        
        if not os.path.exists(metrics_file) or not os.path.exists(config_file):
            continue

        config_df = pd.read_json(config_file)
        if config_df['dataset_cfg']['reader'] != "pypagai.preprocessing.dataset_babi.BaBIDataset":
            continue
            
        db = 'babi' 

        task = config_df['dataset_cfg']['task']
        model = config_df['model_default_cfg']['model'].split('.')[-1]
        
        metrics_df = pd.read_csv(metrics_file)
        acc = metrics_df['accuracy'][0]
        f1 = metrics_df['f1_micro'][0]
        
        result['f1'].append(f1)
        result['db'].append(db)
        result['acc'].append(acc)
        result['task'].append(task)
        result['model'].append(model)

        
new_results = pd.DataFrame(result)

# %%
df
# Out:
#        acc    db                                      db_parameters        f1  \
# 0    0.179  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.138931
# 1    0.175  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.127509
# 2    0.188  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.155791
# 3    0.189  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.150577
# 4    0.183  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.171752
# 5    0.185  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.183060
# 6    0.189  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.189162
# 7    0.183  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.180335
# 8    0.158  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.155079
# 9    0.167  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.164751
# 10   0.174  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.171394
# 11   0.173  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.168159
# 12   0.205  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.173110
# 13   0.231  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.207322
# 14   0.279  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.244128
# 15   0.269  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.220837
# 16   0.321  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.326957
# 17   0.326  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.341059
# 18   0.344  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.357841
# 19   0.301  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.311165
# 20   0.520  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.496963
# 21   0.572  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.571829
# 22   0.610  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.609900
# 23   0.636  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.635999
# 24   0.687  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.351045
# 25   0.682  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.348680
# 26   0.680  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.348187
# 27   0.693  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.355616
# 28   0.495  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.160279
# 29   0.531  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.177217
# ..     ...   ...                                                ...       ...
# 187  0.094  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.042656
# 188  0.093  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.056598
# 189  0.589  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.542721
# 190  0.670  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.610263
# 191  0.653  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.611878
# 192  0.699  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.660970
# 193  0.536  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.536283
# 194  0.646  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.644986
# 195  0.711  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.710546
# 196  0.547  babi  {'__doc__': '
# Dataset configuration
# ', 'size':...  0.546168
# 197  0.953  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.951693
# 198  0.281  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.279020
# 199  0.209  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.208076
# 200  0.958  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.957697
# 201  0.859  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.866201
# 202  0.867  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.866993
# 203  0.855  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.498471
# 204  0.692  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.318030
# 205  0.792  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.777167
# 206  0.910  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.902264
# 207  0.961  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.961720
# 208  0.957  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.956964
# 209  0.952  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.952114
# 210  0.364  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.361489
# 211  0.478  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.477069
# 212  0.456  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.455704
# 213  0.850  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.849458
# 214  0.930  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.929852
# 215  0.126  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.123871
# 216  0.982  babi  {'__doc__': '
# Dataset configuration
# ', 'reader...  0.983335
#
#           model                                          model_cfg  \
# 0    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 1    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 2    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 3    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 4    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 5    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 6    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 7    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 8    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 9    SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 10   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 11   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 12   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 13   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 14   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 15   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 16   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 17   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 18   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 19   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 20   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 21   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 22   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 23   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 24   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 25   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 26   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 27   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 28   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 29   SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# ..          ...                                                ...
# 187  SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 188  SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 189  SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 190  SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 191  SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 192  SimpleLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 193   EmbedLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 194   EmbedLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 195   EmbedLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 196   EmbedLSTM  {'__doc__': '
# Dataset configuration
# ', 'size':...
# 197   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 198   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 199   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 200   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 201   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 202   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 203   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 204   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 205   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 206   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 207   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 208   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 209   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 210   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 211   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 212   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 213   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 214   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 215   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
# 216   N2NMemory  {'__doc__': '
# Dataset configuration
# ', 'reader...
#
#                        __doc__        parser       reader size  \
# 0    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 1    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 2    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 3    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 4    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 5    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 6    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 7    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 8    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 9    \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 10   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 11   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 12   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 13   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 14   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 15   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 16   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 17   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 18   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 19   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 20   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 21   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 22   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 23   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 24   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 25   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 26   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 27   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 28   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 29   \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# ..                         ...           ...          ...  ...
# 187  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 188  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 189  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 190  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 191  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 192  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 193  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 194  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 195  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 196  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 197  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 198  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 199  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 200  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 201  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 202  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 203  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 204  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 205  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 206  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 207  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 208  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 209  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 210  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 211  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 212  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 213  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 214  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 215  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
# 216  \nDataset configuration\n  SimpleParser  BaBIDataset  10k
#
#      strip_sentences  task
# 0              False     1
# 1              False     1
# 2              False     1
# 3              False     1
# 4              False     2
# 5              False     2
# 6              False     2
# 7              False     2
# 8              False     3
# 9              False     3
# 10             False     3
# 11             False     3
# 12             False     4
# 13             False     4
# 14             False     4
# 15             False     4
# 16             False     5
# 17             False     5
# 18             False     5
# 19             False     5
# 20             False     6
# 21             False     6
# 22             False     6
# 23             False     6
# 24             False     7
# 25             False     7
# 26             False     7
# 27             False     7
# 28             False     8
# 29             False     8
# ..               ...   ...
# 187            False    19
# 188            False    19
# 189            False    20
# 190            False    20
# 191            False    20
# 192            False    20
# 193            False     1
# 194            False     1
# 195            False     1
# 196            False     1
# 197            False     1
# 198            False     2
# 199            False     3
# 200            False     4
# 201            False     5
# 202            False     6
# 203            False     7
# 204            False     8
# 205            False     9
# 206            False    10
# 207            False    11
# 208            False    12
# 209            False    13
# 210            False    14
# 211            False    15
# 212            False    16
# 213            False    17
# 214            False    18
# 215            False    19
# 216            False    20
#
# [217 rows x 12 columns]

# %%
# Show best result of each model for each babi task
ddf = df[df['db'] == 'babi']
ddf = pd.concat([new_results, ddf], keys=['acc','f1','db','task','model'])

ddf = df[df['db'] == 'babi']
ddf = ddf.groupby(['db','model','task'])
ddf = ddf.max()
ddf = ddf.reset_index()
ddf[['model','acc','task']].pivot('task', 'model')
# Out:
#                 acc
# model DeepN2NMemory EmbedLSTM N2NMemory     RN SimpleLSTM
# task
# 1             0.963     0.711     0.953    NaN      0.189
# 2             0.325       NaN     0.281    NaN      0.189
# 3             0.251       NaN     0.209    NaN      0.174
# 4             1.000       NaN     0.958    NaN      0.279
# 5             0.826       NaN     0.859    NaN      0.344
# 6             0.972       NaN     0.867    NaN      0.636
# 7             0.904       NaN     0.855    NaN      0.693
# 8             0.802       NaN     0.692    NaN      0.539
# 9             0.962       NaN     0.792    NaN      0.655
# 10            0.956       NaN     0.910    NaN      0.538
# 11            0.985       NaN     0.961    NaN      0.220
# 12            0.967       NaN     0.957    NaN      0.187
# 13            1.000       NaN     0.952  0.907      0.185
# 14            0.412       NaN     0.364  0.449      0.205
# 15            0.536       NaN     0.478  0.597      0.266
# 16            0.451       NaN     0.456  0.454      0.281
# 17            0.958       NaN     0.850  0.662      0.612
# 18            0.957       NaN     0.930  0.972      0.709
# 19            0.086       NaN     0.126  0.151      0.094
# 20            0.983       NaN     0.982  0.976      0.699
